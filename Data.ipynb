# %% [markdown]
# # Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv('MortalityRate.csv')
# Out:
#           Jurisdiction  Value                       Race/ ethnicity  \
# 0                State  166.4    All races/ethnicities (aggregated)
# 1             Allegany  230.6    All races/ethnicities (aggregated)
# 2         Anne Arundel  158.5    All races/ethnicities (aggregated)
# 3       Baltimore City  241.4    All races/ethnicities (aggregated)
# 4     Baltimore County  179.3    All races/ethnicities (aggregated)
# 5              Calvert  188.0    All races/ethnicities (aggregated)
# 6             Caroline  188.4    All races/ethnicities (aggregated)
# 7              Carroll  174.1    All races/ethnicities (aggregated)
# 8                Cecil  205.3    All races/ethnicities (aggregated)
# 9              Charles  166.7    All races/ethnicities (aggregated)
# 10          Dorchester  213.4    All races/ethnicities (aggregated)
# 11           Frederick  165.1    All races/ethnicities (aggregated)
# 12             Garrett  208.6    All races/ethnicities (aggregated)
# ...
